# %% [markdown]
# <a href="https://colab.research.google.com/github/krishnagorrepati/DeepLearningProjects/blob/master/EVA_Session_1A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Session 1A Assignement

# %%
# import the necessary packages
import numpy as np
from urllib.request import urlopen
import cv2
from matplotlib import pyplot as plt

# METHOD #1: OpenCV, NumPy, and urllib
def url_to_image(url):
	# download the image, convert it to a NumPy array, and then read
	# it into OpenCV format
	resp = urlopen(url)
	image = np.asarray(bytearray(resp.read()), dtype="uint8")
	image = cv2.imdecode(image, cv2.IMREAD_COLOR)
 
	# return the image
	return image

# %%
image = url_to_image("https://fontsarena-cd5e.kxcdn.com/wp-content/uploads/2019/04/helvetica-now-font-400x364.png")

# %%
from google.colab.patches import cv2_imshow


cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFDFF672BA8>

# %%
edges = cv2.Canny(image,100,200)

# %%
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=400x364 at 0x7EFDF6ABD0F0>

# %%
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[-1,0,1],[-1,0,1],[-1,0,1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFDF6ABD8D0>

# %%
#Horizontal Edge Detector
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[1,1,1],[0,0,0],[-1,-1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFDF6ABD1D0>

# %%
#Horizontal Edge Detector
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[1,1,1],[0,0,0],[-1,-1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)

#Sobel filter
kernel = np.float32([[1,2,1],[0,0,0],[-1,-2,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFDF6ABE198>
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFDF6ABE160>

# %% [markdown]
# #Blurring
# ### Bluring works on setting the value of the pixel as the total average of all its nearest pixels

# %%
# blur kernel
kernel = np.float32([[1/9,1/9,1/9],[1/9,1/9,1/9],[1/9,1/9,1/9]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFDF6ABDE10>

# %% [markdown]
# #Sharpening
# ### Unlike blurring, sharpening does the opposite and tries to pop out the details in the image. Thus, making pixel value different than its neighbours

# %%
# sharpening kernel
kernel = np.float32([[-1,-1,-1],[-1,9,-1],[-1,-1,-1]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFDF6ABDBA8>

# %%
#Identity Function
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([[0,0,0],[0,1,0],[0,0,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFDF6ABD9E8>

# %%
#45 degree Agle Detector
#kernel = np.ones((3,3),np.float32)/25
kernel = np.float32([
                     [0,1,1],
                     [-1,0,1],
                     [1,1,0]])

dst = cv2.filter2D(image,-1,kernel)
cv2_imshow(dst)
# Out:
# <PIL.Image.Image image mode=RGB size=400x364 at 0x7EFDF6ABDB00>

# %% [markdown]
# ##Refernce Articles
# 1. https://https://en.wikipedia.org/wiki/Kernel_(image_processing)
# 2. https://medium.com/@almutawakel.ali/opencv-filters-arithmetic-operations-2f4ff236d6aa
# 3. https://stackoverflow.com/questions/8547127/how-to-detect-45-degree-edges-in-an-image
